# %%
# Importing python libraries for analysis

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
warnings.filterwarnings('ignore')

# %%
# Creating Dataframes from the excel files

data_folder = "data"

for file in os.listdir(data_folder):
    if file.endswith('.xlsx'):
        file_path = os.path.join(data_folder, file)
        df = pd.read_excel(file_path)
        globals()[f"df_{file.replace(".xlsx","").lower()}"] = df
        print(f"Created DataFrame: df_{file.replace(".xlsx","").lower()}")
# Out:
# Created DataFrame: df_dim_customer
# Created DataFrame: df_dim_date
# Created DataFrame: df_dim_geography
# Created DataFrame: df_dim_products
# Created DataFrame: df_dim_salesperson
# Created DataFrame: df_fact_sales

# %% [markdown]
# ### Cleaning DataFrames (df_dim_customer)

# %%
df_dim_customer.head(5)
# Out:
#   customer_id customer_name     segment    industry
# 0      C00001  Olivia Brown      Retail      Retail
# 1      C00002   Sneha Reddy      Retail          IT
# 2      C00003  Aarav Sharma  Government  Healthcare
# 3      C00004  David Wilson  Government  Healthcare
# 4      C00005    John Singh  Enterprise      Retail

# %%
df_dim_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customer_id    5000 non-null   object
#  1   customer_name  5000 non-null   object
#  2   segment        5000 non-null   object
#  3   industry       5000 non-null   object
# dtypes: object(4)
# memory usage: 156.4+ KB

# %%
# Checking Null Values

df_dim_customer.isnull().sum()
# Out:
# customer_id      0
# customer_name    0
# segment          0
# industry         0
# dtype: int64

# %%
# Checking Duplicated columns

# %%
df_dim_customer[df_dim_customer.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, customer_name, segment, industry]
# Index: []

# %%
# checking distinct customer id across all rows

# %%
df_dim_customer.shape
# Out:
# (5000, 4)

# %%
df_dim_customer['customer_id'].nunique()
# Out:
# 5000

# %%
# checking and fixing datatypes

# %%
df_dim_customer.dtypes
# Out:
# customer_id      object
# customer_name    object
# segment          object
# industry         object
# dtype: object

# %%
# Checking for inconsistent formatting or spelling errors

# %%
df_dim_customer['segment'].unique()
# Out:
# array(['Retail', 'Government', 'Enterprise', 'SMB'], dtype=object)

# %%
df_dim_customer['industry'].unique()
# Out:
# array(['Retail', 'IT', 'Healthcare', 'Finance'], dtype=object)

# %% [markdown]
# ### Cleaning DataFrame (df_dim_geography)

# %%
df_dim_geography.head()
# Out:
#    geo_id         region country          state         city
# 0       1   Asia-Pacific   India      Karnataka    Bengaluru
# 1       2  South America  Brazil      Sao Paulo    Sao Paulo
# 2       3         Europe  France  Ile-de-France        Paris
# 3       4  North America     USA     California  Los Angeles
# 4       5  North America  Canada        Ontario      Toronto

# %%
# Checking data info

# %%
df_dim_geography.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   geo_id   120 non-null    int64
#  1   region   120 non-null    object
#  2   country  120 non-null    object
#  3   state    120 non-null    object
#  4   city     120 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.8+ KB

# %%
# Checking Null values

# %%
df_dim_geography.isnull().sum()
# Out:
# geo_id     0
# region     0
# country    0
# state      0
# city       0
# dtype: int64

# %%
# Checking Duplicate values

# %%
df_dim_geography.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking for distinct geo_id across all rows

# %%
df_dim_geography.shape
# Out:
# (120, 5)

# %%
df_dim_geography['geo_id'].nunique()
# Out:
# 120

# %%
# Checking for inconsistent formatting or spelling errors

# %%
df_dim_geography.columns
# Out:
# Index(['geo_id', 'region', 'country', 'state', 'city'], dtype='object')

# %%
df_dim_geography['region'].unique()
# Out:
# array(['Asia-Pacific', 'South America', 'Europe', 'North America',
#        'Middle East'], dtype=object)

# %%
df_dim_geography['country'].unique()
# Out:
# array(['India', 'Brazil', 'France', 'USA', 'Canada', 'UAE', 'Argentina',
#        'Japan', 'Australia', 'UK', 'Saudi Arabia', 'Germany'],
#       dtype=object)

# %%
df_dim_geography['state'].unique()
# Out:
# array(['Karnataka', 'Sao Paulo', 'Ile-de-France', 'California', 'Ontario',
#        'Texas', 'Dubai', 'Buenos Aires', 'Tokyo', 'Victoria', 'England',
#        'Riyadh', 'Bavaria', 'Tamil Nadu'], dtype=object)

# %%
df_dim_geography['city'].unique()
# Out:
# array(['Bengaluru', 'Sao Paulo', 'Paris', 'Los Angeles', 'Toronto',
#        'Dallas', 'Dubai', 'Buenos Aires', 'Tokyo', 'Melbourne', 'London',
#        'Riyadh', 'Munich', 'Chennai'], dtype=object)

# %% [markdown]
# ### Cleaning DataFrame (df_dim_products)

# %%
df_dim_products.head()
# Out:
#   product_id          product_name    category   brand
# 0      P0001  Business Switch 24 1  Networking    Dell
# 1      P0002        UltraView 24 1     Monitor   Cisco
# 2      P0003     Crystal Display 1     Monitor      HP
# 3      P0004           SSD 512GB 1     Storage   Cisco
# 4      P0005     Security Shield 1    Software  Lenovo

# %%
df_dim_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_id    300 non-null    object
#  1   product_name  300 non-null    object
#  2   category      300 non-null    object
#  3   brand         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
# Checking Null values

# %%
df_dim_products.isnull().sum()
# Out:
# product_id      0
# product_name    0
# category        0
# brand           0
# dtype: int64

# %%
# Checking Duplicate values

# %%
df_dim_products.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Checking for distinct product_id across all rows

# %%
df_dim_products.shape
# Out:
# (300, 4)

# %%
df_dim_products['product_id'].nunique()
# Out:
# 300

# %%
# Checking for inconsistent formatting or spelling errors

# %%
df_dim_products.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'brand'], dtype='object')

# %%
df_dim_products['product_name'].unique()
# Out:
# array(['Business Switch 24 1', 'UltraView 24 1', 'Crystal Display 1',
#        'SSD 512GB 1', 'Security Shield 1', 'SSD 512GB 2', 'SSD 1TB 1',
#        'Business Switch 24 2', 'IdeaPad Slim 1', 'OfficeView 22 1',
#        'Access Point Pro 1', 'OfficeView 22 2', 'USB Drive 128GB 1',
#        'Cloud Backup 1', 'ERP Standard 1', 'OfficeView 22 3',
#        'USB Drive 128GB 2', 'Network Hub 1', 'SSD 512GB 3',
#        'ZenBook Air 1', 'ThinkBook Pro 14 1', 'External HDD 2TB 1',
#        'Portable SSD 1', 'ProColor 27 1', 'SSD 1TB 2', 'VisionPro 27 1',
#        'ERP Standard 2', 'ThinkBook Pro 14 2', 'Network Hub 2',
#        'USB Drive 128GB 3', 'OfficeView 22 4', 'Cloud Backup 2',
#        'WiFi Router AX6000 1', 'Network Hub 3', 'IdeaPad Slim 2',
#        'External HDD 2TB 2', 'USB Drive 128GB 4', 'CRM Essentials 1',
#        'SSD 512GB 4', 'Surface Laptop Go 1', 'Surface Laptop Go 2',
#        'TravelMate Pro 1', 'Analytics Pro 1', 'Enterprise Firewall 1',
# ...

# %%
df_dim_products['category'].unique()
# Out:
# array(['Networking', 'Monitor', 'Storage', 'Software', 'Laptop'],
#       dtype=object)

# %%
df_dim_products['brand'].unique()
# Out:
# array(['Dell', 'Cisco', 'HP', 'Lenovo', 'Microsoft'], dtype=object)

# %% [markdown]
# ### Cleaning DataFrame (df_dim_date)

# %%
df_dim_date.head()
# Out:
#          date  day   day_name  month month_name quarter  year month_year  \
# 0  2022-01-01    1   Saturday      1    January      Q1  2022   Jan-2022
# 1  2022-01-02    2     Sunday      1    January      Q1  2022   Jan-2022
# 2  2022-01-03    3     Monday      1    January      Q1  2022   Jan-2022
# 3  2022-01-04    4    Tuesday      1    January      Q1  2022   Jan-2022
# 4  2022-01-05    5  Wednesday      1    January      Q1  2022   Jan-2022
#
#   year_quarter financial_year financial_quarter
# 0      2022-Q1      FY2021-22                Q4
# 1      2022-Q1      FY2021-22                Q4
# 2      2022-Q1      FY2021-22                Q4
# 3      2022-Q1      FY2021-22                Q4
# 4      2022-Q1      FY2021-22                Q4

# %%
df_dim_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               1461 non-null   object
#  1   day                1461 non-null   int64
#  2   day_name           1461 non-null   object
#  3   month              1461 non-null   int64
#  4   month_name         1461 non-null   object
#  5   quarter            1461 non-null   object
#  6   year               1461 non-null   int64
#  7   month_year         1461 non-null   object
#  8   year_quarter       1461 non-null   object
#  9   financial_year     1461 non-null   object
#  10  financial_quarter  1461 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 125.7+ KB

# %%
# Checking Null Values

# %%
df_dim_date.isnull().sum()
# Out:
# date                 0
# day                  0
# day_name             0
# month                0
# month_name           0
# quarter              0
# year                 0
# month_year           0
# year_quarter         0
# financial_year       0
# financial_quarter    0
# dtype: int64

# %%
# Checking Duplicate values

# %%
df_dim_date.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Verifying datatypes

# %%
df_dim_date.dtypes
# Out:
# date                 datetime64[ns]
# day                           int64
# day_name                     object
# month                         int64
# month_name                   object
# quarter                      object
# year                          int64
# month_year                   object
# year_quarter                 object
# financial_year               object
# financial_quarter            object
# dtype: object

# %%
df_dim_date['date'] = pd.to_datetime(df_dim_date['date'])

# %%
# Checking date range

# %%
print("Min-Date: ",df_dim_date['date'].min() )
print("Max-Date: ",df_dim_date['date'].max() )
# Out:
# Min-Date:  2022-01-01 00:00:00
# Max-Date:  2025-12-31 00:00:00

# %%
#Validate key columns

# %%
df_dim_date['month_name'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
df_dim_date["day_name"].unique()
# Out:
# array(['Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday'], dtype=object)

# %%
df_dim_date['quarter'].unique()
# Out:
# array(['Q1', 'Q2', 'Q3', 'Q4'], dtype=object)

# %%
#Check for continuous dates

df_dim_date['date'].diff().value_counts()
# Out:
# date
# 1 days    1460
# Name: count, dtype: int64

# %% [markdown]
# ### Cleaning DataFrame (df_dim_salesperson)

# %%
df_dim_salesperson.head()
# Out:
#   salesperson_id salesperson_name             designation
# 0           S001   James Anderson         Sales Executive
# 1           S002     Olivia Brown  Senior Sales Executive
# 2           S003     Liam Johnson           Sales Manager
# 3           S004       Emma Davis           Sales Manager
# 4           S005      Noah Wilson  Senior Sales Executive

# %%
df_dim_salesperson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   salesperson_id    100 non-null    object
#  1   salesperson_name  100 non-null    object
#  2   designation       100 non-null    object
# dtypes: object(3)
# memory usage: 2.5+ KB

# %%
# Checking null values

# %%
df_dim_salesperson.isnull().sum()
# Out:
# salesperson_id      0
# salesperson_name    0
# designation         0
# dtype: int64

# %%
# Checking Duplicate Values

# %%
df_dim_salesperson.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Verifying datatypes

# %%
df_dim_salesperson.dtypes
# Out:
# salesperson_id      object
# salesperson_name    object
# designation         object
# dtype: object

# %%
#validdting data

# %%
df_dim_salesperson.columns
# Out:
# Index(['salesperson_id', 'salesperson_name', 'designation'], dtype='object')

# %%
df_dim_salesperson.shape
# Out:
# (100, 3)

# %%
df_dim_salesperson['salesperson_id'].nunique()
# Out:
# 100

# %%
df_dim_salesperson['designation'].unique()
# Out:
# array(['Sales Executive', 'Senior Sales Executive', 'Sales Manager',
#        'Regional Manager'], dtype=object)

# %% [markdown]
# ### Cleaning DataFrame (df_fact_sales)

# %%
df_fact_sales.head()
# Out:
#   order_id  order_date customer_id product_id  geo_id salesperson_id  \
# 0  O000001  2025-08-14      C04634      P0085      62           S069
# 1  O000002  2024-06-15      C03773      P0215      41           S036
# 2  O000003  2022-06-10      C00874      P0080      69           S062
# 3  O000004  2025-02-18      C01009      P0276      55           S032
# 4  O000005  2025-02-14      C04102      P0147     118           S063
#
#    quantity  unit_price  unit_cost  discount_percent  gross_sales  \
# 0        32        1225     796.25                10        39200
# 1        46        1892    1229.80                 5        87032
# 2         9         336     218.40                10         3024
# 3        31        1218     791.70                15        37758
# 4        37        1549    1006.85                 0        57313
#
#    discount_amount  net_sales    profit
# 0           3920.0    35280.0   9800.00
# 1           4351.6    82680.4  26109.60
# ...

# %%
df_fact_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          75000 non-null  object
#  1   order_date        75000 non-null  object
#  2   customer_id       75000 non-null  object
#  3   product_id        75000 non-null  object
#  4   geo_id            75000 non-null  int64
#  5   salesperson_id    75000 non-null  object
#  6   quantity          75000 non-null  int64
#  7   unit_price        75000 non-null  int64
#  8   unit_cost         75000 non-null  float64
#  9   discount_percent  75000 non-null  int64
#  10  gross_sales       75000 non-null  int64
#  11  discount_amount   75000 non-null  float64
#  12  net_sales         75000 non-null  float64
#  13  profit            75000 non-null  float64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 8.0+ MB

# %%
# Checking for null values

# %%
df_fact_sales.isnull().sum()
# Out:
# order_id            0
# order_date          0
# customer_id         0
# product_id          0
# geo_id              0
# salesperson_id      0
# quantity            0
# unit_price          0
# unit_cost           0
# discount_percent    0
# gross_sales         0
# discount_amount     0
# net_sales           0
# profit              0
# dtype: int64

# %%
# Checking duplicate values

# %%
df_fact_sales.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Verifying datatypes

# %%
df_fact_sales.head(2)
# Out:
#   order_id  order_date customer_id product_id  geo_id salesperson_id  \
# 0  O000001  2025-08-14      C04634      P0085      62           S069
# 1  O000002  2024-06-15      C03773      P0215      41           S036
#
#    quantity  unit_price  unit_cost  discount_percent  gross_sales  \
# 0        32        1225     796.25                10        39200
# 1        46        1892    1229.80                 5        87032
#
#    discount_amount  net_sales   profit
# 0           3920.0    35280.0   9800.0
# 1           4351.6    82680.4  26109.6

# %%
df_fact_sales.dtypes
# Out:
# order_id                    object
# order_date          datetime64[ns]
# customer_id                 object
# product_id                  object
# geo_id                       int64
# salesperson_id              object
# quantity                     int64
# unit_price                 float64
# unit_cost                  float64
# discount_percent             int64
# gross_sales                  int64
# discount_amount            float64
# net_sales                  float64
# profit                     float64
# dtype: object

# %%
df_fact_sales['order_date'] = pd.to_datetime(df_fact_sales['order_date'])

# %%
df_fact_sales['unit_price'] = df_fact_sales['unit_price'].astype('float')

# %% [markdown]
# ### Converting cleaned dataframes into csv files

# %%
output_folder = os.path.join("data", "cleaned_data")
os.makedirs(output_folder, exist_ok=True)


df_dim_customer.to_csv(os.path.join(output_folder, "dim_customer.csv"), index=False)
df_dim_date.to_csv(os.path.join(output_folder, "dim_date.csv"), index=False)
df_dim_geography.to_csv(os.path.join(output_folder, "dim_geography.csv"), index=False)
df_dim_products.to_csv(os.path.join(output_folder, "dim_products.csv"), index=False)
df_dim_salesperson.to_csv(os.path.join(output_folder, "dim_salesperson.csv"), index=False)
df_fact_sales.to_csv(os.path.join(output_folder, "fact_sales.csv"), index=False)
